# %%
import pandas as pd

# %%
data = pd.read_csv("../../8-1.csv") # appro
data_2 = pd.read_csv("../../8-2.csv") # member
data_3 = pd.read_csv("../../8-3.csv") #
data_4 = pd.read_csv("../../8-4.csv") # appro

# %%
data
# Out:
#               발급회원번호  최종이용일자_일시불  최종이용일자_체크  최종이용일자_할부  이용개월수_일시불_R12M  \
# 0        SYN_2467848    20180816   20180831   20170709              12
# 1         SYN_970249    20180831   20180701   20161129              12
# 2        SYN_2469653    20180831      10101   20141108              12
# 3         SYN_753729    20180823      10101   20170928              12
# 4         SYN_860484    20180827   20180808      10101              12
# ...              ...         ...        ...        ...             ...
# 2999995  SYN_1966491    20180809   20180825   20180714              12
# 2999996  SYN_1128432    20180804      10101   20180616              12
# 2999997   SYN_492747    20180807   20180215   20180819              12
# 2999998   SYN_188884    20180806      10101   20180626              12
# 2999999  SYN_2355455    20180816   20180818   20180427              12
#
#          이용개월수_할부_R12M  이용개월수_체크_R12M  이용금액_일시불_B0M  이용금액_체크_B0M  이용금액_할부_B0M  \
# ...

# %%
data_2
# Out:
#               발급회원번호  남녀구분코드   연령 VIP등급코드  회원여부_이용가능  회원여부_이용가능_CA  \
# 0        SYN_2518672       1  30대       _          0             0
# 1        SYN_1509599       1  30대       _          0             0
# 2        SYN_1513112       2  50대       _          0             0
# 3        SYN_1516329       1  30대       _          0             0
# 4        SYN_1523933       1  30대       _          0             0
# ...              ...     ...  ...     ...        ...           ...
# 2999995  SYN_1426911       2  40대      06          1             1
# 2999996   SYN_490126       1  40대      07          1             0
# 2999997   SYN_498094       2  30대      06          1             1
# 2999998   SYN_154670       1  40대      07          1             1
# 2999999  SYN_1829463       1  30대      06          1             1
#
#          회원여부_이용가능_카드론  입회경과개월수_신용  탈회횟수_누적  최종탈회후경과월  탈회횟수_발급6개월이내  마케팅동의여부  \
# 0                    0          74        0         0             0        0
# ...

# %%
data_3
# Out:
#               발급회원번호  유효카드수_신용체크  유효카드수_신용  유효카드수_체크
# 0        SYN_2510861           2         2         0
# 1        SYN_2514103           1         1         0
# 2        SYN_2521009           1         1         0
# 3        SYN_2521290           1         1         0
# 4        SYN_2534733           0         0         0
# ...              ...         ...       ...       ...
# 2999995   SYN_443735           7         5         2
# 2999996   SYN_449189           7         5         2
# 2999997  SYN_1497713           7         4         3
# 2999998  SYN_1243738           8         5         3
# 2999999  SYN_1404185           8         5         3
#
# [3000000 rows x 4 columns]

# %%
data_4
# Out:
#               발급회원번호  최대이용금액_일시불_R12M  최대이용금액_할부_R12M  최대이용금액_체크_R12M  \
# 0        SYN_2599110          1422592          400118               0
# 1        SYN_1678927          1118593          229740               0
# 2        SYN_1175610          1066176          274220               0
# 3        SYN_2273417          1563551          363444               0
# 4         SYN_792784          1575793          658524               0
# ...              ...              ...             ...             ...
# 2999995   SYN_425633            34347               0               0
# 2999996    SYN_91318            92821               0               0
# 2999997   SYN_961792                0               0               0
# 2999998   SYN_962008          1708743               0          344920
# 2999999  SYN_1707518           723815               0               0
#
#          이용금액_업종기준  이용후경과월_일시불  이용후경과월_체크  이용후경과월_할부
# 0           852879           0         12         10
# ...

# %%
merged_df = pd.merge(data,data_2,on='발급회원번호',how='inner')

# %%
merged_df2 = pd.merge(merged_df,data_3, on='발급회원번호',how='inner')

# %%
last = pd.merge(merged_df2, data_4, on='발급회원번호', how = 'inner')

# %%
last
# Out:
#               발급회원번호  최종이용일자_일시불  최종이용일자_체크  최종이용일자_할부  이용개월수_일시불_R12M  \
# 0        SYN_2467848    20180816   20180831   20170709              12
# 1         SYN_970249    20180831   20180701   20161129              12
# 2        SYN_2469653    20180831      10101   20141108              12
# 3         SYN_753729    20180823      10101   20170928              12
# 4         SYN_860484    20180827   20180808      10101              12
# ...              ...         ...        ...        ...             ...
# 2999995  SYN_1966491    20180809   20180825   20180714              12
# 2999996  SYN_1128432    20180804      10101   20180616              12
# 2999997   SYN_492747    20180807   20180215   20180819              12
# 2999998   SYN_188884    20180806      10101   20180626              12
# 2999999  SYN_2355455    20180816   20180818   20180427              12
#
#          이용개월수_할부_R12M  이용개월수_체크_R12M  이용금액_일시불_B0M  이용금액_체크_B0M  이용금액_할부_B0M  \
# ...

# %%
result = pd.read_csv("../../data/5_20.csv")

# %%
result
# Out:
#         VIP등급코드  남녀구분코드  연령  회원여부_이용가능  회원여부_이용가능_CA  회원여부_이용가능_카드론  \
# 0             _       2  40          0             0              0
# 1             _       1  30          0             0              0
# 2             _       2  60          0             0              0
# 3             _       2  30          0             0              0
# 4             _       1  40          0             0              0
# ...         ...     ...  ..        ...           ...            ...
# 2999995      06       1  40          1             1              0
# 2999996      06       1  50          1             1              1
# 2999997      07       1  30          1             1              1
# 2999998      07       1  40          1             1              1
# 2999999       _       2  30          1             1              0
#
#          입회경과개월수_신용  탈회횟수_누적  최종탈회후경과월  탈회횟수_발급6개월이내  ...  이용후경과월_일시불  \
# 0               166        0         0             0  ...           0
# ...

# %%
# 발급회원번호를 제외한 result의 컬럼 순서 기준으로
desired_order = [col for col in result.columns if col != '발급회원번호']

# 발급회원번호를 첫 번째로 두고 나머지는 result 순서대로
new_column_order = ['발급회원번호'] + desired_order

# last에 그 순서 적용
last = last[new_column_order]

# %%
last
# Out:
#               발급회원번호 VIP등급코드  남녀구분코드   연령  회원여부_이용가능  회원여부_이용가능_CA  \
# 0        SYN_2467848      07       2  20대          1             0
# 1         SYN_970249       _       1  40대          1             1
# 2        SYN_2469653      07       1  40대          1             1
# 3         SYN_753729       _       2  30대          1             1
# 4         SYN_860484      06       1  30대          1             1
# ...              ...     ...     ...  ...        ...           ...
# 2999995  SYN_1966491      07       2  40대          1             1
# 2999996  SYN_1128432       _       2  40대          1             1
# 2999997   SYN_492747      07       2  20대          1             1
# 2999998   SYN_188884      07       2  50대          1             0
# 2999999  SYN_2355455      07       1  30대          1             1
#
#          회원여부_이용가능_카드론  입회경과개월수_신용  탈회횟수_누적  최종탈회후경과월  ...  이용후경과월_일시불  \
# 0                    0          13        0         0  ...           0
# ...

# %%
# last.to_csv("8_data_non_preprocessing.csv",index=False)

# %%
last.columns
# Out:
# Index(['발급회원번호', '최종이용일자_일시불', '최종이용일자_체크', '최종이용일자_할부', '이용개월수_일시불_R12M',
#        '이용개월수_할부_R12M', '이용개월수_체크_R12M', '이용금액_일시불_B0M', '이용금액_체크_B0M',
#        '이용금액_할부_B0M', '이용건수_일시불_B0M', '이용건수_체크_B0M', '이용건수_할부_B0M', '남녀구분코드',
#        '연령', 'VIP등급코드', '회원여부_이용가능', '회원여부_이용가능_CA', '회원여부_이용가능_카드론',
#        '입회경과개월수_신용', '탈회횟수_누적', '최종탈회후경과월', '탈회횟수_발급6개월이내', '마케팅동의여부',
#        '이용금액_R3M_신용', '유효카드수_신용체크', '유효카드수_신용', '유효카드수_체크', '최대이용금액_일시불_R12M',
#        '최대이용금액_할부_R12M', '최대이용금액_체크_R12M', '이용금액_업종기준', '이용후경과월_일시불',
#        '이용후경과월_체크', '이용후경과월_할부'],
#       dtype='object')

# %%
def preprocess_feature(data):
    data['VIP등급코드'] = data['VIP등급코드'].str.replace("_","0").astype(int)
    
    data['연령'] = data['연령'].str.replace('대|이상','',regex=True).astype(int)
    # 이용건수 합치기 예시
    data['이용건수_B0M'] = data[['이용건수_일시불_B0M', '이용건수_체크_B0M', '이용건수_할부_B0M']].sum(axis=1)

    # 이용금액 합치기 예시
    data['이용금액_B0M'] = data[['이용금액_일시불_B0M', '이용금액_체크_B0M', '이용금액_할부_B0M']].sum(axis=1)

    # 이용개월수 합치기 예시
    data['이용개월수_R12M'] = data[['이용개월수_일시불_R12M', '이용개월수_할부_R12M', '이용개월수_체크_R12M']].sum(axis=1)

    # 유효카드수 합치기 예시
    data['유효카드수_총합'] = data[['유효카드수_신용체크', '유효카드수_신용', '유효카드수_체크']].sum(axis=1)

    # 최종 이용일자 최신값 선택 (datetime이라 .max()가 정확히 동작함)
    data['최종이용일자_종합'] = data[['최종이용일자_일시불', '최종이용일자_체크', '최종이용일자_할부']].max(axis=1)

    # 필요 없는 원본 컬럼 제거 (존재하는 컬럼만)
    cols_to_drop = [
        '이용건수_일시불_B0M', '이용건수_체크_B0M', '이용건수_할부_B0M',
        '이용금액_일시불_B0M', '이용금액_체크_B0M', '이용금액_할부_B0M',
        '이용개월수_일시불_R12M', '이용개월수_할부_R12M', '이용개월수_체크_R12M',
        '유효카드수_신용체크', '유효카드수_신용', '유효카드수_체크',
        '최종이용일자_일시불', '최종이용일자_체크', '최종이용일자_할부','발급회원번호'
    ]
    drop_cols = [col for col in cols_to_drop if col in data.columns]
    data.drop(columns=drop_cols, inplace=True)

    return data

# %%
preprocess_feature(last)
# Out:
#               발급회원번호  남녀구분코드  연령  VIP등급코드  회원여부_이용가능  회원여부_이용가능_CA  \
# 0        SYN_2467848       2  20        7          1             0
# 1         SYN_970249       1  40        0          1             1
# 2        SYN_2469653       1  40        7          1             1
# 3         SYN_753729       2  30        0          1             1
# 4         SYN_860484       1  30        6          1             1
# ...              ...     ...  ..      ...        ...           ...
# 2999995  SYN_1966491       2  40        7          1             1
# 2999996  SYN_1128432       2  40        0          1             1
# 2999997   SYN_492747       2  20        7          1             1
# 2999998   SYN_188884       2  50        7          1             0
# 2999999  SYN_2355455       1  30        7          1             1
#
#          회원여부_이용가능_카드론  입회경과개월수_신용  탈회횟수_누적  최종탈회후경과월  ...  최대이용금액_체크_R12M  \
# 0                    0          13        0         0  ...         3375912
# ...

# %%
# last.to_csv("8_data_index.csv",index=False) #발급회원번호가 포함된 csv파일일

# %%
model_data = pd.read_csv("../../model_data.csv")

# %%
set(last) - set(model_data)
# Out:
# set()

# %%
set(model_data) - set(last)
# Out:
# {'Unnamed: 0', '청구금액_B0'}

# %%
model_data = model_data.drop(columns=['Unnamed: 0','청구금액_B0'])

# %%
last = last[model_data.columns]

# %%
last
# Out:
#          VIP등급코드  남녀구분코드  연령  회원여부_이용가능  회원여부_이용가능_CA  회원여부_이용가능_카드론  \
# 0              7       2  20          1             0              0
# 1              0       1  40          1             1              0
# 2              7       1  40          1             1              1
# 3              0       2  30          1             1              1
# 4              6       1  30          1             1              1
# ...          ...     ...  ..        ...           ...            ...
# 2999995        7       2  40          1             1              0
# 2999996        0       2  40          1             1              1
# 2999997        7       2  20          1             1              0
# 2999998        7       2  50          1             0              1
# 2999999        7       1  30          1             1              0
#
#          입회경과개월수_신용  탈회횟수_누적  최종탈회후경과월  탈회횟수_발급6개월이내  ...  이용후경과월_체크  \
# ...

# %%
model_data
# Out:
#          VIP등급코드  남녀구분코드  연령  회원여부_이용가능  회원여부_이용가능_CA  회원여부_이용가능_카드론  \
# 0              0       2  40          0             0              0
# 1              0       1  30          0             0              0
# 2              0       2  60          0             0              0
# 3              0       2  30          0             0              0
# 4              0       1  40          0             0              0
# ...          ...     ...  ..        ...           ...            ...
# 2999995        6       1  40          1             1              0
# 2999996        6       1  50          1             1              1
# 2999997        7       1  30          1             1              1
# 2999998        7       1  40          1             1              1
# 2999999        0       2  30          1             1              0
#
#          입회경과개월수_신용  탈회횟수_누적  최종탈회후경과월  탈회횟수_발급6개월이내  ...  이용후경과월_체크  \
# ...

# %%
last
# Out:
#          VIP등급코드  남녀구분코드  연령  회원여부_이용가능  회원여부_이용가능_CA  회원여부_이용가능_카드론  \
# 0              7       2  20          1             0              0
# 1              0       1  40          1             1              0
# 2              7       1  40          1             1              1
# 3              0       2  30          1             1              1
# 4              6       1  30          1             1              1
# ...          ...     ...  ..        ...           ...            ...
# 2999995        7       2  40          1             1              0
# 2999996        0       2  40          1             1              1
# 2999997        7       2  20          1             1              0
# 2999998        7       2  50          1             0              1
# 2999999        7       1  30          1             1              0
#
#          입회경과개월수_신용  탈회횟수_누적  최종탈회후경과월  탈회횟수_발급6개월이내  ...  이용후경과월_체크  \
# ...

# %%
# last.to_csv('8_data.csv',index=False) # 발급회원번호가 제외된 csv 파일
