# %%
import pandas as pd

# %%
member = pd.read_csv("D://117.금융 합성데이터//3.개방데이터//1.데이터//1. 합성데이터//01.카드 회원정보//201807_회원정보.csv")

# %%
member['VIP등급코드'].value_counts()
# Out:
# VIP등급코드
# _     2402408
# 07     436556
# 06     159485
# 04       1352
# 05        199
# Name: count, dtype: int64

# %%
vip_member = member[member['VIP등급코드'] != '_']

# %%
columns = [  '기준년월',
  '발급회원번호',
  '남녀구분코드',
  '연령',
  'VIP등급코드',
  'Life_Stage',
  '최상위카드등급코드',
  '마케팅동의여부',
  '소지여부_신용',
  '입회일자_신용',
  '입회경과개월수_신용',
  '회원여부_연체',
  # '가입통신회사코드',
  '탈회횟수_누적',
  '최종탈회후경과월',
  '탈회횟수_발급6개월이내',
  '탈회횟수_발급1년이내',
  '유효카드수_신용체크',
  '유효카드수_신용',
  '유효카드수_신용_가족',
  '유효카드수_체크',
  '유효카드수_체크_가족',
  '이용가능카드수_신용체크',
  '이용가능카드수_신용',
  '이용가능카드수_신용_가족',
  '이용가능카드수_체크',
  '이용가능카드수_체크_가족',
  '이용카드수_신용체크',
  '이용카드수_신용',
  '이용카드수_신용_가족',
  '이용카드수_체크',
  '이용카드수_체크_가족',
  '이용금액_R3M_신용체크',
  '이용금액_R3M_신용',
  '이용금액_R3M_신용_가족',
  '이용금액_R3M_체크',
  '이용금액_R3M_체크_가족',
  '최종카드발급일자',
  '연회비발생카드수_B0M',
  '연회비할인카드수_B0M',
  '기본연회비_B0M',
  '제휴연회비_B0M',
  '할인금액_기본연회비_B0M',
  '할인금액_제휴연회비_B0M',
  '청구금액_기본연회비_B0M',
  '청구금액_제휴연회비_B0M',
  '카드신청건수'
]

# %%
vip_member = vip_member[columns]

# %%
vip_member
# Out:
#            기준년월       발급회원번호  남녀구분코드     연령 VIP등급코드  Life_Stage 최상위카드등급코드  \
# 0        201807        SYN_0       2    40대      07  5.자녀성장기(2)         _
# 8        201807        SYN_8       1    20대      07    1.Single         _
# 9        201807        SYN_9       1    30대      06     3.자녀출산기         _
# 17       201807       SYN_17       2  70대이상      07        7.노령         _
# 18       201807       SYN_18       1    40대      07  4.자녀성장기(1)         _
# ...         ...          ...     ...    ...     ...         ...       ...
# 2999978  201807  SYN_2999978       2    40대      06  5.자녀성장기(2)         _
# 2999982  201807  SYN_2999982       1    40대      07  4.자녀성장기(1)         _
# 2999984  201807  SYN_2999984       2    30대      07     3.자녀출산기         _
# 2999990  201807  SYN_2999990       2    30대      07     2.가족형성기         _
# 2999996  201807  SYN_2999996       1    50대      07  5.자녀성장기(2)         _
#
#          마케팅동의여부  소지여부_신용   입회일자_신용  ...    최종카드발급일자  연회비발생카드수_B0M  \
# ...

# %%
vip_member.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 597592 entries, 0 to 2999996
# Data columns (total 46 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   기준년월            597592 non-null  int64
#  1   발급회원번호          597592 non-null  object
#  2   남녀구분코드          597592 non-null  int64
#  3   연령              597592 non-null  object
#  4   VIP등급코드         597592 non-null  object
#  5   Life_Stage      597592 non-null  object
#  6   최상위카드등급코드       597592 non-null  object
#  7   마케팅동의여부         597592 non-null  int64
#  8   소지여부_신용         597592 non-null  int64
#  9   입회일자_신용         597592 non-null  int64
#  10  입회경과개월수_신용      597592 non-null  int64
#  11  회원여부_연체         597592 non-null  int64
#  12  탈회횟수_누적         597592 non-null  int64
#  13  최종탈회후경과월        597592 non-null  int64
#  14  탈회횟수_발급6개월이내    597592 non-null  int64
#  15  탈회횟수_발급1년이내     597592 non-null  int64
#  16  유효카드수_신용체크      597592 non-null  int64
# ...

# %%
vip_member.describe()
# Out:
#            기준년월         남녀구분코드        마케팅동의여부        소지여부_신용       입회일자_신용  \
# count  597592.0  597592.000000  597592.000000  597592.000000  5.975920e+05
# mean   201807.0       1.419776       0.776498       0.999321  2.009401e+07
# std         0.0       0.493523       0.416592       0.026056  6.452785e+04
# min    201807.0       1.000000       0.000000       0.000000  1.991050e+07
# 25%    201807.0       1.000000       1.000000       1.000000  2.005070e+07
# 50%    201807.0       1.000000       1.000000       1.000000  2.011110e+07
# 75%    201807.0       2.000000       1.000000       1.000000  2.014100e+07
# max    201807.0       2.000000       1.000000       1.000000  2.018060e+07
#
#           입회경과개월수_신용        회원여부_연체        탈회횟수_누적       최종탈회후경과월  \
# count  597592.000000  597592.000000  597592.000000  597592.000000
# mean      105.476717       0.030026       0.415390      26.245117
# std        77.343992       0.170658       0.595419      39.153093
# ...

# %%
vip_member.isna().sum()
# Out:
# 기준년월                0
# 발급회원번호              0
# 남녀구분코드              0
# 연령                  0
# VIP등급코드             0
# Life_Stage          0
# 최상위카드등급코드           0
# 마케팅동의여부             0
# 소지여부_신용             0
# 입회일자_신용             0
# 입회경과개월수_신용          0
# 회원여부_연체             0
# 탈회횟수_누적             0
# 최종탈회후경과월            0
# 탈회횟수_발급6개월이내        0
# 탈회횟수_발급1년이내         0
# 유효카드수_신용체크          0
# 유효카드수_신용            0
# 유효카드수_신용_가족         0
# 유효카드수_체크            0
# 유효카드수_체크_가족         0
# 이용가능카드수_신용체크        0
# 이용가능카드수_신용          0
# 이용가능카드수_신용_가족       0
# 이용가능카드수_체크          0
# 이용가능카드수_체크_가족       0
# 이용카드수_신용체크          0
# 이용카드수_신용            0
# 이용카드수_신용_가족         0
# 이용카드수_체크            0
# 이용카드수_체크_가족         0
# 이용금액_R3M_신용체크       0
# 이용금액_R3M_신용         0
# 이용금액_R3M_신용_가족      0
# 이용금액_R3M_체크         0
# 이용금액_R3M_체크_가족      0
# 최종카드발급일자          409
# 연회비발생카드수_B0M        0
# 연회비할인카드수_B0M        0
# 기본연회비_B0M           0
# 제휴연회비_B0M           0
# ...

# %%
credit = pd.read_csv("D://117.금융 합성데이터//3.개방데이터//1.데이터//1. 합성데이터//02.카드 신용정보//201807_신용정보.csv")

# %%
credit
# Out:
#            기준년월       발급회원번호   최초한도금액  카드이용한도금액   CA한도금액  일시상환론한도금액  월상환론한도금액  \
# 0        201807        SYN_0        0   1935492   727075          0         0
# 1        201807        SYN_1        0    999681   571881    4199692   9061169
# 2        201807        SYN_2        0   8529934  2919555    4800228  15676315
# 3        201807        SYN_3   999660   4132759  1453506    8999881  20604475
# 4        201807        SYN_4        0    489924   903676          0         0
# ...         ...          ...      ...       ...      ...        ...       ...
# 2999995  201807  SYN_2999995        0   2999861        0          0         0
# 2999996  201807  SYN_2999996  3450486   4519301  1676973          0  20659138
# 2999997  201807  SYN_2999997        0   4935589  1999198    4320646   8880732
# 2999998  201807  SYN_2999998        0   1995707   570722          0         0
# 2999999  201807  SYN_2999999        0    397800        0          0         0
#
# ...

# %%
columns = [
    '발급회원번호',
    '카드이용한도금액',
    'CA한도금액',
    '일시상환론한도금액',
    '월상환론한도금액',
    'CA이자율_할인전',
    'CL이자율_할인전',
    'RV일시불이자율_할인전',
    '연체감액여부_R3M',
    '한도심사요청건수',
    '한도요청거절건수',
    '한도심사요청후경과월',
    '한도심사거절후경과월',
    '시장단기연체여부_R6M',
    '시장단기연체여부_R3M',
    '시장연체상환여부_R6M',
    '시장연체상환여부_R3M',
    'rv최초시작후경과일'
]

# %%
credit = credit[columns]

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 18 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   발급회원번호        object
#  1   카드이용한도금액      int64
#  2   CA한도금액        int64
#  3   일시상환론한도금액     int64
#  4   월상환론한도금액      int64
#  5   CA이자율_할인전     float64
#  6   CL이자율_할인전     float64
#  7   RV일시불이자율_할인전  float64
#  8   연체감액여부_R3M    int64
#  9   한도심사요청건수      int64
#  10  한도요청거절건수      int64
#  11  한도심사요청후경과월    int64
#  12  한도심사거절후경과월    int64
#  13  시장단기연체여부_R6M  int64
#  14  시장단기연체여부_R3M  int64
#  15  시장연체상환여부_R6M  int64
#  16  시장연체상환여부_R3M  int64
#  17  rv최초시작후경과일    int64
# dtypes: float64(3), int64(14), object(1)
# memory usage: 412.0+ MB

# %%
credit.isna().sum()
# Out:
# 발급회원번호          0
# 카드이용한도금액        0
# CA한도금액          0
# 일시상환론한도금액       0
# 월상환론한도금액        0
# CA이자율_할인전       0
# CL이자율_할인전       0
# RV일시불이자율_할인전    0
# 연체감액여부_R3M      0
# 한도심사요청건수        0
# 한도요청거절건수        0
# 한도심사요청후경과월      0
# 한도심사거절후경과월      0
# 시장단기연체여부_R6M    0
# 시장단기연체여부_R3M    0
# 시장연체상환여부_R6M    0
# 시장연체상환여부_R3M    0
# rv최초시작후경과일      0
# dtype: int64

# %%
merged_df = pd.merge(vip_member, credit, on = '발급회원번호', how = 'inner')

# %%
merged_df
# Out:
#           기준년월       발급회원번호  남녀구분코드     연령 VIP등급코드  Life_Stage 최상위카드등급코드  \
# 0       201807        SYN_0       2    40대      07  5.자녀성장기(2)         _
# 1       201807        SYN_8       1    20대      07    1.Single         _
# 2       201807        SYN_9       1    30대      06     3.자녀출산기         _
# 3       201807       SYN_17       2  70대이상      07        7.노령         _
# 4       201807       SYN_18       1    40대      07  4.자녀성장기(1)         _
# ...        ...          ...     ...    ...     ...         ...       ...
# 597587  201807  SYN_2999978       2    40대      06  5.자녀성장기(2)         _
# 597588  201807  SYN_2999982       1    40대      07  4.자녀성장기(1)         _
# 597589  201807  SYN_2999984       2    30대      07     3.자녀출산기         _
# 597590  201807  SYN_2999990       2    30대      07     2.가족형성기         _
# 597591  201807  SYN_2999996       1    50대      07  5.자녀성장기(2)         _
#
#         마케팅동의여부  소지여부_신용   입회일자_신용  ...  연체감액여부_R3M  한도심사요청건수  한도요청거절건수  \
# ...

# %%
merged_df['Life_Stage'].value_counts()
# Out:
# Life_Stage
# 4.자녀성장기(1)    226263
# 5.자녀성장기(2)    142918
# 3.자녀출산기        72385
# 2.가족형성기        64786
# 6.자녀출가기        38335
# 7.노령           37518
# 1.Single       15387
# Name: count, dtype: int64

# %%
merged_df['Life_Stage'] = merged_df['Life_Stage'].str.extract(r'^(\d)').astype(int)

# %%
merged_df
# Out:
#           기준년월       발급회원번호  남녀구분코드     연령 VIP등급코드  Life_Stage 최상위카드등급코드  \
# 0       201807        SYN_0       2    40대      07           5         _
# 1       201807        SYN_8       1    20대      07           1         _
# 2       201807        SYN_9       1    30대      06           3         _
# 3       201807       SYN_17       2  70대이상      07           7         _
# 4       201807       SYN_18       1    40대      07           4         _
# ...        ...          ...     ...    ...     ...         ...       ...
# 597587  201807  SYN_2999978       2    40대      06           5         _
# 597588  201807  SYN_2999982       1    40대      07           4         _
# 597589  201807  SYN_2999984       2    30대      07           3         _
# 597590  201807  SYN_2999990       2    30대      07           2         _
# 597591  201807  SYN_2999996       1    50대      07           5         _
#
#         마케팅동의여부  소지여부_신용   입회일자_신용  ...  연체감액여부_R3M  한도심사요청건수  한도요청거절건수  \
# ...

# %%
merged_df = merged_df.drop(columns = '입회일자_신용')

# %%
merged_df[merged_df['rv최초시작후경과일'] > 100000]
# Out:
#           기준년월       발급회원번호  남녀구분코드     연령 VIP등급코드  Life_Stage 최상위카드등급코드  \
# 0       201807        SYN_0       2    40대      07           5         _
# 1       201807        SYN_8       1    20대      07           1         _
# 2       201807        SYN_9       1    30대      06           3         _
# 3       201807       SYN_17       2  70대이상      07           7         _
# 5       201807       SYN_32       2    30대      07           4         _
# ...        ...          ...     ...    ...     ...         ...       ...
# 597587  201807  SYN_2999978       2    40대      06           5         _
# 597588  201807  SYN_2999982       1    40대      07           4         _
# 597589  201807  SYN_2999984       2    30대      07           3         _
# 597590  201807  SYN_2999990       2    30대      07           2         _
# 597591  201807  SYN_2999996       1    50대      07           5         _
#
#         마케팅동의여부  소지여부_신용  입회경과개월수_신용  ...  연체감액여부_R3M  한도심사요청건수  한도요청거절건수  \
# ...

# %%
merged_df =merged_df.drop(columns = 'rv최초시작후경과일')

# %%
merged_df
# Out:
#           기준년월       발급회원번호  남녀구분코드     연령 VIP등급코드  Life_Stage 최상위카드등급코드  \
# 0       201807        SYN_0       2    40대      07           5         _
# 1       201807        SYN_8       1    20대      07           1         _
# 2       201807        SYN_9       1    30대      06           3         _
# 3       201807       SYN_17       2  70대이상      07           7         _
# 4       201807       SYN_18       1    40대      07           4         _
# ...        ...          ...     ...    ...     ...         ...       ...
# 597587  201807  SYN_2999978       2    40대      06           5         _
# 597588  201807  SYN_2999982       1    40대      07           4         _
# 597589  201807  SYN_2999984       2    30대      07           3         _
# 597590  201807  SYN_2999990       2    30대      07           2         _
# 597591  201807  SYN_2999996       1    50대      07           5         _
#
#         마케팅동의여부  소지여부_신용  입회경과개월수_신용  ...  RV일시불이자율_할인전  연체감액여부_R3M  한도심사요청건수  \
# ...

# %%
merged_df['연령'] = merged_df['연령'].str.extract('(\d+)').astype(int)

# %%
merged_df
# Out:
#           기준년월       발급회원번호  남녀구분코드  연령 VIP등급코드  Life_Stage 최상위카드등급코드  \
# 0       201807        SYN_0       2  40      07           5         _
# 1       201807        SYN_8       1  20      07           1         _
# 2       201807        SYN_9       1  30      06           3         _
# 3       201807       SYN_17       2  70      07           7         _
# 4       201807       SYN_18       1  40      07           4         _
# ...        ...          ...     ...  ..     ...         ...       ...
# 597587  201807  SYN_2999978       2  40      06           5         _
# 597588  201807  SYN_2999982       1  40      07           4         _
# 597589  201807  SYN_2999984       2  30      07           3         _
# 597590  201807  SYN_2999990       2  30      07           2         _
# 597591  201807  SYN_2999996       1  50      07           5         _
#
#         마케팅동의여부  소지여부_신용  입회경과개월수_신용  ...  RV일시불이자율_할인전  연체감액여부_R3M  한도심사요청건수  \
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597592 entries, 0 to 597591
# Data columns (total 61 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   기준년월            597592 non-null  int64
#  1   발급회원번호          597592 non-null  object
#  2   남녀구분코드          597592 non-null  int64
#  3   연령              597592 non-null  int64
#  4   VIP등급코드         597592 non-null  object
#  5   Life_Stage      597592 non-null  int64
#  6   최상위카드등급코드       597592 non-null  object
#  7   마케팅동의여부         597592 non-null  int64
#  8   소지여부_신용         597592 non-null  int64
#  9   입회경과개월수_신용      597592 non-null  int64
#  10  회원여부_연체         597592 non-null  int64
#  11  탈회횟수_누적         597592 non-null  int64
#  12  최종탈회후경과월        597592 non-null  int64
#  13  탈회횟수_발급6개월이내    597592 non-null  int64
#  14  탈회횟수_발급1년이내     597592 non-null  int64
#  15  유효카드수_신용체크      597592 non-null  int64
#  16  유효카드수_신용        597592 non-null  int64
# ...

# %%
merged_df['최상위카드등급코드'].value_counts()
# Out:
# 최상위카드등급코드
# _    564166
# 2     15057
# 1      8448
# 4      6271
# 3      3650
# Name: count, dtype: int64

# %%
merged_df['최상위카드등급코드'] = merged_df['최상위카드등급코드'].replace('_','0').astype(int)

# %%
merged_df
# Out:
#           기준년월       발급회원번호  남녀구분코드  연령 VIP등급코드  Life_Stage  최상위카드등급코드  \
# 0       201807        SYN_0       2  40      07           5          0
# 1       201807        SYN_8       1  20      07           1          0
# 2       201807        SYN_9       1  30      06           3          0
# 3       201807       SYN_17       2  70      07           7          0
# 4       201807       SYN_18       1  40      07           4          0
# ...        ...          ...     ...  ..     ...         ...        ...
# 597587  201807  SYN_2999978       2  40      06           5          0
# 597588  201807  SYN_2999982       1  40      07           4          0
# 597589  201807  SYN_2999984       2  30      07           3          0
# 597590  201807  SYN_2999990       2  30      07           2          0
# 597591  201807  SYN_2999996       1  50      07           5          0
#
#         마케팅동의여부  소지여부_신용  입회경과개월수_신용  ...  RV일시불이자율_할인전  연체감액여부_R3M  한도심사요청건수  \
# ...

# %%
merged_df['탈회횟수_누적'].value_counts()
# Out:
# 탈회횟수_누적
# 0    382728
# 1    181494
# 2     33370
# Name: count, dtype: int64

# %%
data = pd.read_csv("청구금액.csv")

# %%
merged_df = pd.merge(merged_df, data, on="발급회원번호", how = 'inner')

# %%
merged_df
# Out:
#           기준년월       발급회원번호  남녀구분코드  연령 VIP등급코드  Life_Stage  최상위카드등급코드  \
# 0       201807        SYN_0       2  40      07           5          0
# 1       201807        SYN_8       1  20      07           1          0
# 2       201807        SYN_9       1  30      06           3          0
# 3       201807       SYN_17       2  70      07           7          0
# 4       201807       SYN_18       1  40      07           4          0
# ...        ...          ...     ...  ..     ...         ...        ...
# 597587  201807  SYN_2999978       2  40      06           5          0
# 597588  201807  SYN_2999982       1  40      07           4          0
# 597589  201807  SYN_2999984       2  30      07           3          0
# 597590  201807  SYN_2999990       2  30      07           2          0
# 597591  201807  SYN_2999996       1  50      07           5          0
#
#         마케팅동의여부  소지여부_신용  입회경과개월수_신용  ...  한도요청거절건수  한도심사요청후경과월  한도심사거절후경과월  \
# ...

# %%
merged_df[merged_df['청구금액_B0']==0]
# Out:
#           기준년월       발급회원번호  남녀구분코드  연령 VIP등급코드  Life_Stage  최상위카드등급코드  \
# 103     201807      SYN_468       1  50      06           5          0
# 115     201807      SYN_524       1  40      07           4          0
# 116     201807      SYN_526       2  50      06           5          0
# 118     201807      SYN_528       2  30      07           4          0
# 125     201807      SYN_582       2  30      07           3          0
# ...        ...          ...     ...  ..     ...         ...        ...
# 597499  201807  SYN_2999573       2  30      07           3          0
# 597512  201807  SYN_2999634       1  40      07           4          0
# 597517  201807  SYN_2999653       1  20      07           1          0
# 597563  201807  SYN_2999860       1  60      07           6          0
# 597579  201807  SYN_2999923       2  50      07           5          3
#
#         마케팅동의여부  소지여부_신용  입회경과개월수_신용  ...  한도요청거절건수  한도심사요청후경과월  한도심사거절후경과월  \
# ...

# %%
merged_df[merged_df['청구금액_R3M']==0]
# Out:
#           기준년월       발급회원번호  남녀구분코드  연령 VIP등급코드  Life_Stage  최상위카드등급코드  \
# 103     201807      SYN_468       1  50      06           5          0
# 115     201807      SYN_524       1  40      07           4          0
# 116     201807      SYN_526       2  50      06           5          0
# 118     201807      SYN_528       2  30      07           4          0
# 125     201807      SYN_582       2  30      07           3          0
# ...        ...          ...     ...  ..     ...         ...        ...
# 597407  201807  SYN_2999115       1  50      07           5          0
# 597465  201807  SYN_2999398       1  30      07           3          3
# 597466  201807  SYN_2999399       1  50      07           5          0
# 597499  201807  SYN_2999573       2  30      07           3          0
# 597563  201807  SYN_2999860       1  60      07           6          0
#
#         마케팅동의여부  소지여부_신용  입회경과개월수_신용  ...  한도요청거절건수  한도심사요청후경과월  한도심사거절후경과월  \
# ...
